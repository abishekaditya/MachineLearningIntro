# %%
import pandas as pd

# %%
header =["age","workclass","fnlwgt","education","education-num","marital-status","occupation","relationship","race","sex","capital-gain","capital-loss","hours-per-week","native-country"]
adult = pd.read_csv("adult.data", index_col=False, names = header)

# %%
adult = adult[['age','workclass']]
adult_counts = adult['workclass'].value_counts()
print(adult_counts)
# Out:
#   File "<ipython-input-7-86a92bdfaf38>", line 3
#     print adult_counts
#                      ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
# %matplotlib inline  
adult_counts.plot(kind = 'barh', rot = 0)
